# %% [markdown]
# # Dy ε comparison (AGB models from Excel)
#
# This notebook runs the same logic as `dy_epsilon_agb.py` and shows the output table.

# %%
import pandas as pd
from dy_epsilon_agb import run

EXCEL = 'AGB_models.xlsx'
MODELS = [
    {'sheet':'2M_ref','label':'2 Msun default','ls':'--'},
    {'sheet':'2M_new','label':'2 Msun new','ls':'-'},
    {'sheet':'3M_ref','label':'3 Msun default','ls':'--'},
    {'sheet':'3M_new','label':'3 Msun new','ls':'-'},
]

df = run(EXCEL, MODELS)
df
