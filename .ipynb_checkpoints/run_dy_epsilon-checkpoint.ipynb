# %% [markdown]
# # Dy ε comparison (AGB models from Excel)
#
# This notebook runs the same logic as `dy_epsilon_agb.py` and shows the output table.

# %%
import pandas as pd
from dy_epsilon_agb import run

EXCEL = 'AGB_models.xlsx'
MODELS = [
    {'sheet':'2M_ref','label':'2 Msun default','ls':'--'},
    {'sheet':'2M_new','label':'2 Msun new','ls':'-'},
    {'sheet':'3M_ref','label':'3 Msun default','ls':'--'},
    {'sheet':'3M_new','label':'3 Msun new','ls':'-'},
]

df = run(EXCEL, MODELS)
df
# Out:
#             model   sheet stage_used    f_best   chi2_min   chi2_red  \
# 0  2 Msun default  2M_ref     TDU_13  0.000084  21.385037  10.692518
# 1      3 Msun new  3M_new     TDU_25  0.000151  22.724593  11.362296
# 2  3 Msun default  3M_ref     TDU_25  0.000143  32.840583  16.420291
# 3      2 Msun new  2M_new     TDU_13  0.000088  41.928907  20.964453
#
#      eps160    eps161        eps162    eps163  eps164
# 0  5.546308 -0.436514  0.000000e+00 -1.124698     0.0
# 1  6.141330 -0.285392 -1.110223e-12 -1.047769     0.0
# 2  5.281994 -0.512780  0.000000e+00 -1.147188     0.0
# 3  6.296457 -0.191232 -1.110223e-12 -1.018899     0.0
